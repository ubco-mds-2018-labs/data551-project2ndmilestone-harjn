# %%
import pandas as pd
import plotly
import plotly.graph_objs as go
import plotly.plotly as py

plotly.tools.set_credentials_file(username='harjn',api_key='zYlSMFG3CGKLVrNX3CEm')

books = pd.read_csv('books.csv', encoding = "ISO-8859-1")
ratings = pd.read_csv('ratings.csv')

# %%
books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                       authors  original_publication_year  \
# 0  9.780439e+12               Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPrÃ©                     1997.0
# 2  9.780316e+12               Stephenie Meyer                     2005.0
# 3  9.780061e+12                    Harper Lee                     1960.0
# 4  9.780743e+12           F. Scott Fitzgerald                     1925.0
#
# ...

# %%
x=books.groupby(["original_publication_year"]).mean()

# %%
x.head()
# Out:
#                            book_id  goodreads_book_id  best_book_id  \
# original_publication_year
# -1750.0                     2076.0            19351.0       19351.0
# -762.0                      2142.0             1375.0        1375.0
# -750.0                      3253.5           267830.0      267830.0
# -720.0                        79.0             1381.0        1381.0
# -560.0                      1120.0            21348.0       21348.0
#
#                              work_id  books_count        isbn13  \
# original_publication_year
# -1750.0                    3802528.0        266.0  9.780141e+12
# -762.0                     1474309.0        255.0  9.780148e+12
# -750.0                     1907469.0        933.0  9.780416e+12
# -720.0                     3356006.0       1703.0  9.780143e+12
# -560.0                      868263.0        942.0  9.780193e+12
#
#                            average_rating  ratings_count  work_ratings_count  \
# original_publication_year
# ...

# %%
sorted(books['original_publication_year'].unique())
# Out:
# [-750.0,
#  -720.0,
#  -500.0,
#  975.0,
#  1390.0,
#  1513.0,
#  1595.0,
#  1598.0,
#  1600.0,
#  1603.0,
#  1605.0,
#  1606.0,
#  1611.0,
#  1719.0,
#  1726.0,
#  1759.0,
#  1811.0,
#  1813.0,
#  1814.0,
#  1815.0,
#  1817.0,
#  1818.0,
#  1838.0,
#  1843.0,
#  1844.0,
#  1847.0,
#  1849.0,
#  1850.0,
#  1851.0,
#  1852.0,
#  1856.0,
#  1859.0,
#  1860.0,
#  1862.0,
#  1865.0,
#  1866.0,
#  1868.0,
#  1869.0,
#  1876.0,
#  1877.0,
#  1880.0,
#  1882.0,
#  1884.0,
#  1886.0,
#  1887.0,
#  1891.0,
#  1892.0,
#  1895.0,
#  1897.0,
#  1899.0,
#  1900.0,
#  1901.0,
#  1902.0,
#  1903.0,
#  1904.0,
#  1905.0,
#  1908.0,
#  1909.0,
#  1911.0,
#  1915.0,
#  1922.0,
#  1923.0,
#  1925.0,
#  1926.0,
#  1929.0,
#  1931.0,
#  1932.0,
#  1935.0,
#  1936.0,
#  1937.0,
#  1938.0,
#  1939.0,
#  1940.0,
#  1942.0,
#  1943.0,
#  1945.0,
#  1946.0,
#  1947.0,
#  1948.0,
#  1949.0,
#  1950.0,
#  1951.0,
#  1952.0,
#  1953.0,
#  1954.0,
#  1955.0,
#  1956.0,
#  1957.0,
#  1958.0,
#  1959.0,
#  1960.0,
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
# book_id                      10000 non-null int64
# goodreads_book_id            10000 non-null int64
# best_book_id                 10000 non-null int64
# work_id                      10000 non-null int64
# books_count                  10000 non-null int64
# isbn                         9300 non-null object
# isbn13                       9415 non-null float64
# authors                      10000 non-null object
# original_publication_year    9979 non-null float64
# original_title               9415 non-null object
# title                        10000 non-null object
# language_code                8916 non-null object
# average_rating               10000 non-null float64
# ratings_count                10000 non-null int64
# work_ratings_count           10000 non-null int64
# work_text_reviews_count      10000 non-null int64
# ...

# %%
books[books['original_publication_year']<0]
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 78         79               1381          1381   3356006         1703
# 340       341               1371          1371   3293141         1726
# 402       403              10534         10534   3200649         1865
# 771       772              30289         30289   1625515          842
# 823       824               1554          1554   3098166          498
# 1098     1099              57854         67896    100074         1265
# 1119     1120              21348         21348    868263          942
# 1279     1280              12914         12914    288738          830
# 1520     1521               7728          7728   1052210          423
# 2051     2052               1540          1540      5672          331
# 2075     2076              19351         19351   3802528          266
# 2141     2142               1375          1375   1474309          255
# ...

# %%
sorted(books['original_publication_year'].unique().astype(int))
# Out:
# [-9223372036854775808,
#  -1750,
#  -762,
#  -750,
#  -720,
#  -560,
#  -500,
#  -476,
#  -458,
#  -441,
#  -440,
#  -431,
#  -430,
#  -411,
#  -401,
#  -400,
#  -390,
#  -385,
#  -380,
#  -350,
#  -335,
#  -330,
#  -300,
#  -17,
#  8,
#  119,
#  180,
#  397,
#  609,
#  800,
#  975,
#  1120,
#  1273,
#  1308,
#  1320,
#  1353,
#  1380,
#  1390,
#  1418,
#  1485,
#  1513,
#  1516,
#  1519,
#  1532,
#  1550,
#  1554,
#  1563,
#  1589,
#  1590,
#  1591,
#  1592,
#  1593,
#  1594,
#  1595,
#  1596,
#  1597,
#  1598,
#  1599,
#  1600,
#  1601,
#  1603,
#  1604,
#  1605,
#  1606,
#  1611,
#  1623,
#  1637,
#  1641,
#  1645,
#  1651,
#  1664,
#  1666,
#  1667,
#  1677,
#  1678,
#  1689,
#  1691,
#  1719,
#  1722,
#  1726,
#  1729,
#  1748,
#  1749,
#  1759,
#  1762,
#  1764,
#  1767,
#  1774,
#  1776,
#  1781,
#  1782,
#  1785,
#  1787,
#  1789,
#  1791,
#  1796,
#  1798,
#  1807,
#  1808,
#  1811,
#  1812,
#  1813,
#  1814,
#  1815,
#  1817,
#  1818,
#  1819,
#  1820,
#  1825,
#  1826,
# ...

# %%
books['original_publication_year'].unique()
# Out:
# array([ 2008.,  1997.,  2005.,  1960.,  1925.,  2012.,  1937.,  1951.,
#         2000.,  1813.,  2003.,  2011.,  1949.,  1945.,  1947.,  2009.,
#         1999.,  1954.,  2010.,  2002.,  1998.,  2007.,  1595.,  1988.,
#         1993.,  1950.,  1996.,  2006.,  1868.,  1847.,  2001.,  1953.,
#         1974.,  1979.,  1932.,  1884.,  1952.,  2015.,  1995.,  2004.,
#         1969.,  1936.,  1985.,  1818.,  1977.,  1811.,  -720.,  1946.,
#         1859.,  1990.,  1964.,  1989.,  1958.,  1973.,  1967.,  1911.,
#         1891.,  1897.,  1963.,  1844.,  2013.,  1862.,  1961.,  1876.,
#         1962.,  1955.,  1991.,  1600.,  1965.,  1939.,  1908.,  1850.,
#         2014.,  1606.,  1860.,  1942.,  1978.,  1815.,  1877.,  1986.,
#         1866.,  1922.,  1987.,  1851.,  1982.,  1843.,  1976.,  1994.,
#         1915.,  1956.,    nan,  1980.,  1865.,  1817.,  1957.,  1926.,
#         1943.,  1938.,  1966.,  1981.,  2016.,  1992.,  1984.,  1972.,
# ...

# %%
books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                       authors  original_publication_year  \
# 0  9.780439e+12               Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPrÃ©                     1997.0
# 2  9.780316e+12               Stephenie Meyer                     2005.0
# 3  9.780061e+12                    Harper Lee                     1960.0
# 4  9.780743e+12           F. Scott Fitzgerald                     1925.0
#
# ...

# %%
books.groupby(["authors"]).count().sort_values(["book_id"],ascending=False)
# Out:
#                                                    book_id  goodreads_book_id  \
# authors
# Stephen King                                            60                 60
# Nora Roberts                                            59                 59
# Dean Koontz                                             47                 47
# Terry Pratchett                                         42                 42
# Agatha Christie                                         39                 39
# Meg Cabot                                               37                 37
# James Patterson                                         36                 36
# David Baldacci                                          34                 34
# John Grisham                                            33                 33
# J.D. Robb                                               33                 33
# Laurell K. Hamilton                                     30                 30
# ...

# %%
books[books['original_publication_year'].isnull()]
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 219       220            3609760       3609760   3652511           20
# 975       976              90072         90072  24501333            3
# 3505     3506             856917        856917   3874446            9
# 4228     4229                 36            36      4414           12
# 4247     4248            8724779       8724779  13597737            1
# 4409     4410             349254        349254     17150           10
# 4707     4708            9832370       9832370  27881851            1
# 4770     4771            5171894       5171894   5238959           50
# 4877     4878           17733861      17733861  24809815           11
# 5609     5610            1044141       1044141   1673783           68
# 5871     5872            9748274       9748274  14637456           33
# 6428     6429              48811         48811     47752            4
# ...

# %%
#removing the books without publication years
bookswyears=books.dropna(subset=["original_publication_year"])

# %%
bookswyears["intpubyears"]=bookswyears["original_publication_year"].astype(int)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
bookswyears.sort_values(["intpubyears"],ascending=False)
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 7372     7373           23766634      23766634  25126752           18
# 9391     9392           29906980      29906980  50281866            2
# 7559     7560           27883214      27883214  45697227           51
# 5883     5884           30831912      30831912  51396954           38
# 8684     8685           28965131      28965131  49193186           30
# 9579     9580           32848471      32848471  53450421            8
# 8281     8282           29430788      29430788  49695344           14
# 7466     7467           28016509      28016509  48027180           63
# 7239     7240           27824826      27824826  47804789           45
# 7447     7448           30226723      30226723  42721001           11
# 9568     9569           32075671      32075671  49638190           36
# 7070     7071           27810589      27810589  45688257           11
# ...

# %%
#sorting by the integer years and geting the mean of the ratings of the different books made in those years

b=bookswyears.groupby("intpubyears").mean().sort_values(['intpubyears'],ascending=False)
b=b.reset_index()

# %%
#sorting by the integer years and geting the count of the ratings of the different books made in those years
b2=bookswyears.groupby("intpubyears").count().sort_values(['intpubyears'],ascending=False)
b2=b2.reset_index()

# %%
import plotly.graph_objs as go
import plotly.plotly as py

import numpy as np

trace1 = go.Scatter(
    x = bookswyears['intpubyears'],
    y = bookswyears['average_rating'],
    mode='markers',
    marker=dict(
        cmax=5,
            cmin=3,
        size=10,
        color =bookswyears['average_rating'], #set color equal to a variable
        colorscale='Viridis',
        showscale=True
    )
)
data = [trace1]

#py.iplot(data, filename='scatter-plot-with-colorscale')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~harjn/21.embed" height="525px" width="100%"></iframe>

# %%
import plotly.graph_objs as go
import plotly.plotly as py

import numpy as np

trace1 = go.Scatter(
    x = b['intpubyears'],
    y = b['average_rating'],
    mode='markers',
    marker=dict(
        cmax=5,
            cmin=3,
        size=10,
        color =b['average_rating'], #set color equal to a variable
        colorscale='Viridis',
        showscale=True
    )
)
data = [trace1]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='scatter-plot-with-colorscale')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~harjn/21.embed" height="525px" width="100%"></iframe>

# %%
import plotly.graph_objs as go
import plotly.plotly as py

import numpy as np

trace1 = go.Scatter(
    x = b2['intpubyears'],
    y = b2['average_rating'],
    mode='markers',
    marker=dict(
        #size=5
    )

)
data = [trace1]

layout = go.Layout(
        title="Number of Books in Dataset by Publication Year",
        xaxis=dict(
        title='Publication Year',
        titlefont=dict(
            size=18,
            color='#7f7f7f'
        )
    ),
        yaxis=dict(
        title='Books/Sets',
        titlefont=dict(
            size=18,
            color='#7f7f7f'
        )
    ), 
        margin=go.layout.Margin(
        b=200
    ),
    barmode='stack'
)


fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='scatter-plot-with-colorscale')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~harjn/21.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

data = [go.Bar(
            x=b2['intpubyears'],
            y=b2['average_rating']
    )]

py.iplot(data, filename='basic-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~harjn/17.embed" height="525px" width="100%"></iframe>

# %%
books["title"]"original_title",
# Out:
# 0                 The Hunger Games (The Hunger Games, #1)
# 1       Harry Potter and the Sorcerer's Stone (Harry P...
# 2                                 Twilight (Twilight, #1)
# 3                                   To Kill a Mockingbird
# 4                                        The Great Gatsby
# 5                                  The Fault in Our Stars
# 6                                              The Hobbit
# 7                                  The Catcher in the Rye
# 8                   Angels & Demons  (Robert Langdon, #1)
# 9                                     Pride and Prejudice
# 10                                        The Kite Runner
# 11                              Divergent (Divergent, #1)
# 12                                                   1984
# 13                                            Animal Farm
# 14                              The Diary of a Young Girl
# 15       The Girl with the Dragon Tattoo (Millennium, #1)
# ...

# %%
#do the number of authors affect the average rating or the number of reviews?? 
#as time goes on do authors ratings increase in general? (for the ones with more than 1 title of course)

# %%
books["original_title"]
# Out:
# 0                                        The Hunger Games
# 1                Harry Potter and the Philosopher's Stone
# 2                                                Twilight
# 3                                   To Kill a Mockingbird
# 4                                        The Great Gatsby
# 5                                  The Fault in Our Stars
# 6                      The Hobbit or There and Back Again
# 7                                  The Catcher in the Rye
# 8                                        Angels & Demons
# 9                                     Pride and Prejudice
# 10                                       The Kite Runner
# 11                                              Divergent
# 12                                   Nineteen Eighty-Four
# 13                             Animal Farm: A Fairy Story
# 14      Het Achterhuis: Dagboekbrieven 14 juni 1942 - ...
# 15                                 MÃ¤n som hatar kvinnor
# ...

# %%
ratings=ratings.reset_index()
ratings.head()
# Out:
#    index  user_id  book_id  rating
# 0      0        1      258       5
# 1      1        2     4081       4
# 2      2        2      260       5
# 3      3        2     9296       5
# 4      4        2     2318       3

# %%
trace0 = go.Scatter(
        x=ratings['index'],
        y=ratings['rating'],
        mode='lines+markers',
        marker=dict(size=10, color='blue'),
        line = dict(
        color = ('blue'),
            width = 4))

layout = go.Layout(
    title='Funding Sources Over Time',
    yaxis=dict(title='Total Disbursement, $(Millions)'),
    xaxis=dict(title='Years',dtick=1),
    width=1100,
    height=500,
    legend=dict(x=0.55, y=1.05)
)
data = [trace0]

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='donut')
#plotly.offline.iplot(fig)
# Out:
# /opt/conda/lib/python3.6/site-packages/plotly/plotly/plotly.py:230: UserWarning:
#
# Woah there! Look at all those points! Due to browser limitations, the Plotly SVG drawing functions have a hard time graphing more than 500k data points for line charts, or 40k points for other types of charts. Here are some suggestions:
# (1) Use the `plotly.graph_objs.Scattergl` trace object to generate a WebGl graph.
# (2) Trying using the image API to return an image instead of a graph URL
# (3) Use matplotlib
# (4) See if you can create your visualization with fewer data points
#
# If the visualization you're using aggregates points (e.g., box plot, histogram, etc.) you can disregard this warning.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(ratings['index'], ratings['rating'], color='r')
plt.title('European Union (EU)')
plt.ylabel('Funding')
plt.xlabel('Date')
#plt.xticks([])
plt.tight_layout() 
plt.show()

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np

trace = go.Scattergl(
    x = ratings['index'],
    y = ratings['rating'],
    mode = 'markers',
    marker = dict(
        color = '#FFBAD2',
        line = dict(width = 1)
    )
)
data = [trace]
py.iplot(data, filename='compare_webgl')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/plotly/api/v1/utils.py in validate_response(response)
#      23     try:
# ---> 24         parsed_content = response.json()
#      25     except ValueError:
#
# /opt/conda/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#
# /opt/conda/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#
# /opt/conda/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     338         """
# ...

# %%
labels2 = d2['donors']
values2 = d2['total_disbursements']

trace1 = go.Pie(labels=labels2, values=values2,
               hoverinfo='label+percent', textinfo='value', 
               textfont=dict(size=20),
               hole=0.5,
               marker=dict(line=dict(color='#000000', width=2)))

layout = go.Layout(title='Correlation between sectors and funding sources',
                  width=1000,height=750,margin = go.layout.Margin(b=200),
                  annotations=[dict(text='Basic Education',showarrow=False,font=dict(size=20))])


data = [trace1]

fig = go.Figure(data=data,layout=layout)
plotly.offline.iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-d382f8654ca9> in <module>
# ----> 1 labels2 = d2['donors']
#       2 values2 = d2['total_disbursements']
#       3
#       4 trace1 = go.Pie(labels=labels2, values=values2,
#       5                hoverinfo='label+percent', textinfo='value',
#
# NameError: name 'd2' is not defined

# %%
#create a bar grap hof this too
numberofratingtypes=[books["ratings_1"].sum(),books["ratings_2"].sum(),books["ratings_3"].sum(),books["ratings_4"].sum(),books["ratings_5"].sum()]
ratinglabels=[1,2,3,4,5]

trace1 = go.Pie(labels=ratinglabels, values=numberofratingtypes,
               hoverinfo='label+percent', textinfo='value', 
               textfont=dict(size=20),
               hole=0.5,
               marker=dict(line=dict(color='#000000', width=2)))

layout = go.Layout(title='Number of Each Rating',
                  width=1000,height=750,margin = go.layout.Margin(b=200),
                  annotations=[dict(text='',showarrow=False,font=dict(size=20))])


data = [trace1]

fig = go.Figure(data=data,layout=layout)
py.iplot(fig, filename='donut')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~harjn/4.embed" height="750px" width="1000px"></iframe>

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
# book_id                      10000 non-null int64
# goodreads_book_id            10000 non-null int64
# best_book_id                 10000 non-null int64
# work_id                      10000 non-null int64
# books_count                  10000 non-null int64
# isbn                         9300 non-null object
# isbn13                       9415 non-null float64
# authors                      10000 non-null object
# original_publication_year    9979 non-null float64
# original_title               9415 non-null object
# title                        10000 non-null object
# language_code                8916 non-null object
# average_rating               10000 non-null float64
# ratings_count                10000 non-null int64
# work_ratings_count           10000 non-null int64
# work_text_reviews_count      10000 non-null int64
# ...

# %%
books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                       authors  original_publication_year  \
# 0  9.780439e+12               Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPrÃ©                     1997.0
# 2  9.780316e+12               Stephenie Meyer                     2005.0
# 3  9.780061e+12                    Harper Lee                     1960.0
# 4  9.780743e+12           F. Scott Fitzgerald                     1925.0
#
# ...

# %%
avratingofusers=ratings.groupby("user_id").mean()
avratingofusers.head()
# Out:
#                 index      book_id    rating
# user_id
# 1        1.351137e+06   893.521368  3.589744
# 2        3.756393e+06  2013.169231  4.415385
# 3        9.735230e+04  2470.043956  1.736264
# 4        5.122147e+04   514.888060  3.768657
# 5        4.296435e+06  3381.820000  4.040000

# %%
#adding the number of ratings per user
numratingsperuser=ratings.groupby("user_id").count()
avratingofusers['count']=numratingsperuser['rating']
avratingofusers.head()
# Out:
#                 index      book_id    rating  count
# user_id
# 1        1.351137e+06   893.521368  3.589744    117
# 2        3.756393e+06  2013.169231  4.415385     65
# 3        9.735230e+04  2470.043956  1.736264     91
# 4        5.122147e+04   514.888060  3.768657    134
# 5        4.296435e+06  3381.820000  4.040000    100

# %%
finalaverage=avratingofusers.groupby('count').mean()
finalaverage=finalaverage.reset_index()
finalaverage.head()
# Out:
#    count         index      book_id    rating
# 0     19  4.252473e+06  4395.210526  4.473684
# 1     20  3.771137e+06  1142.700000  4.150000
# 2     21  4.365703e+06  3619.857143  3.650794
# 3     22  4.401469e+06  3828.503497  3.720280
# 4     23  3.247931e+06  3180.713043  3.660870

# %%
finalaverage['count'].max()
# Out:
# 200

# %%
trace = go.Bar(x=finalaverage['count'],y=finalaverage['rating'],marker=dict(color=finalaverage['count'],colorscale='Jet',showscale=False,reversescale=True)
               ,text=finalaverage['count'],textposition='auto')

data= [trace]
layout = go.Layout(title='Rating versus number of reviews',yaxis=dict(title='Sources',automargin=True),
                  xaxis=dict(title="Total Funding (Millions)",automargin=True),showlegend=False,width=1050,height=700)

fig=go.Figure(data=data,layout=layout)
py.iplot(fig, filename='donut2')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~harjn/15.embed" height="700px" width="1050px"></iframe>

# %%
numratingsperuser.groupby('rating').count().head()
# Out:
#         index  book_id
# rating
# 19          1        1
# 20          1        1
# 21          3        3
# 22         13       13
# 23          5        5

# %%
import plotly.plotly as py
import plotly.graph_objs as go



data = [go.Bar(
            x=books['original_title'],
            y=books['average_rating']
    )]

py.iplot(data, filename='basic-bar')
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~harjn/17.embed" height="525px" width="100%"></iframe>

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
# book_id                      10000 non-null int64
# goodreads_book_id            10000 non-null int64
# best_book_id                 10000 non-null int64
# work_id                      10000 non-null int64
# books_count                  10000 non-null int64
# isbn                         9300 non-null object
# isbn13                       9415 non-null float64
# authors                      10000 non-null object
# original_publication_year    9979 non-null float64
# original_title               9415 non-null object
# title                        10000 non-null object
# language_code                8916 non-null object
# average_rating               10000 non-null float64
# ratings_count                10000 non-null int64
# work_ratings_count           10000 non-null int64
# work_text_reviews_count      10000 non-null int64
# ...

# %%
brc=books.sort_values("ratings_count", ascending=False)
brc.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                       authors  original_publication_year  \
# 0  9.780439e+12               Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPrÃ©                     1997.0
# 2  9.780316e+12               Stephenie Meyer                     2005.0
# 3  9.780061e+12                    Harper Lee                     1960.0
# 4  9.780743e+12           F. Scott Fitzgerald                     1925.0
#
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

data = [go.Bar(
            x=brc.head()['title'],
            y=brc.head()['average_rating']
    )]

py.iplot(data, filename='basic-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~harjn/17.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x=brc.head()['title'],
    y=brc.head()['ratings_1'],
    name='Ratings of 1'
)
trace2 = go.Bar(
    x=brc.head()['title'],
    y=brc.head()['ratings_2'],
    name='Ratings of 2'
)

trace3 = go.Bar(
    x=brc.head()['title'],
    y=brc.head()['ratings_3'],
    name='Ratings of 3'
)

trace4 = go.Bar(
    x=brc.head()['title'],
    y=brc.head()['ratings_4'],
    name='Ratings of 4'
)
trace5 = go.Bar(
    x=brc.head()['title'],
    y=brc.head()['ratings_5'],
    name='Ratings of 5'
)


data = [trace1, trace2, trace3, trace4, trace5]
layout = go.Layout(
        title="Books/Sets With the Highest Number of Ratings",
        xaxis=dict(
        title='Title',
        titlefont=dict(
            size=18,
            color='#7f7f7f'
        )
    ),
        yaxis=dict(
        title='Number of Ratings',
        titlefont=dict(
            size=18,
            color='#7f7f7f'
        )
    ), 
        margin=go.layout.Margin(
        b=200
    ),
    barmode='stack'
)



fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~harjn/19.embed" height="525px" width="100%"></iframe>

# %%
brc.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                       authors  original_publication_year  \
# 0  9.780439e+12               Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPrÃ©                     1997.0
# 2  9.780316e+12               Stephenie Meyer                     2005.0
# 3  9.780061e+12                    Harper Lee                     1960.0
# 4  9.780743e+12           F. Scott Fitzgerald                     1925.0
#
# ...

# %%
bra=books.sort_values("average_rating", ascending=False)
bra.head()
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 3627     3628              24812         24812     25599           14
# 3274     3275                  8             8  21457576           11
# 861       862           17332218      17332218  16482835           34
# 8853     8854              95602         95602    920037            6
# 7946     7947            5031805       5031805  40769318           96
#
#             isbn        isbn13                                     authors  \
# 3627   740748475  9.780741e+12                              Bill Watterson
# 3274   439682584  9.780440e+12                J.K. Rowling, Mary GrandPrÃ©
# 861    765326361  9.780765e+12                           Brandon Sanderson
# 8853   842339523  9.780842e+12                             Francine Rivers
# 7946  1433502410  9.781434e+12  Anonymous, Lane T. Dennis, Wayne A. Grudem
#
#       original_publication_year                  original_title  ...  \
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

data = [go.Bar(
            x=bra.head(100)['title'],
            y=bra.head(100)['average_rating']
    )]

py.iplot(data, filename='basic-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~harjn/17.embed" height="525px" width="100%"></iframe>

# %%
#breakdown of the number of ratings for the 5 books with the highest average ratings 
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x=bra.head()['title'],
    y=bra.head()['ratings_1'],
    name='Ratings of 1'
)
trace2 = go.Bar(
    x=bra.head()['title'],
    y=bra.head()['ratings_2'],
    name='Ratings of 2'
)

trace3 = go.Bar(
    x=bra.head()['title'],
    y=bra.head()['ratings_3'],
    name='Ratings of 3'
)

trace4 = go.Bar(
    x=bra.head()['title'],
    y=bra.head()['ratings_4'],
    name='Ratings of 4'
)
trace5 = go.Bar(
    x=bra.head()['title'],
    y=bra.head()['ratings_5'],
    name='Ratings of 5'
)


data = [trace1, trace2, trace3, trace4, trace5]
layout = go.Layout(
            title="Books/Sets With the Highest Average Ratings",
        xaxis=dict(
        title='Title',
        titlefont=dict(
            size=18,
            color='#7f7f7f'
        )
    ),
        yaxis=dict(
        title='Number of Ratings',
        titlefont=dict(
            size=18,
            color='#7f7f7f'
        )
    ), 
    margin=go.layout.Margin(
        b=200
    ),
    barmode='stack'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='stacked-bar2')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~harjn/23.embed" height="525px" width="100%"></iframe>

# %%
bra.head(20)['title']
# Out:
# 3627                       The Complete Calvin and Hobbes
# 3274    Harry Potter Boxed Set, Books 1-5 (Harry Potte...
# 861        Words of Radiance (The Stormlight Archive, #2)
# 8853                             Mark of the Lion Trilogy
# 7946                                      ESV Study Bible
# 4482    It's a Magical World: A Calvin and Hobbes Coll...
# 6360    There's Treasure Everywhere: A Calvin and Hobb...
# 421              Harry Potter Boxset (Harry Potter, #1-7)
# 3752         Harry Potter Collection (Harry Potter, #1-6)
# 6919                  The Indispensable Calvin and Hobbes
# 6589    The Authoritative Calvin and Hobbes: A Calvin ...
# 9565    Attack of the Deranged Mutant Killer Monster S...
# 1307    A Court of Mist and Fury (A Court of Thorns an...
# 8977                          The Revenge of the Baby-Sat
# 9075      Preach My Gospel: A Guide To Missionary Service
# 7253    Homicidal Psycho Jungle Cat: A Calvin and Hobb...
# ...
